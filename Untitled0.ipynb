# %% [markdown]
# <a href="https://colab.research.google.com/github/alcantaralucas/elementos_finitos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a5472b58-8b1f-4742-8dee-ca069f08a77a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5472b58-8b1f-4742-8dee-ca069f08a77a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test2.csv to test2 (1).csv
# ...

# %%
velo = pd.read_csv('test2.csv')

# %%
velo
# Out:
#         Block Name  Point ID  Points_0  ...  alpha.water         p     p_rgh
# 0     internalMesh         0  0.000275  ...     0.964777   98.6230   96.2471
# 1     internalMesh         1  0.000275  ...     0.938074  141.9420  139.4520
# 2     internalMesh         2  0.000275  ...     0.995717   44.6880   42.4260
# 3     internalMesh         3  0.000275  ...     0.999977   35.7888   33.6511
# 4     internalMesh         4  0.000275  ...     1.000000   37.9286   35.9166
# ...            ...       ...       ...  ...          ...       ...       ...
# 1695  internalMesh      1695  0.000275  ...     1.000000   37.0986   36.8472
# 1696  internalMesh      1696  0.000275  ...     1.000000   37.0985   36.8471
# 1697  internalMesh      1697  0.000275  ...     1.000000   36.9406   36.8149
# 1698  internalMesh      1698  0.000275  ...     1.000000   36.9405   36.8148
# 1699  internalMesh      1699  0.000275  ...     1.000000   36.7964   36.7964
#
# [1700 rows x 13 columns]

# %%
fig = go.Figure(data = 
    go.Contour(
        z=velo["alpha.water"],
        x=velo["Points_0"],
        y=velo["Points_1"]
    ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0a3a03e5-76da-4688-a38b-8e5a95f42848" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0a3a03e5-76da-4688-a38b-8e5a95f42848")) {
#                     Plotly.newPlot(
#                         '0a3a03e5-76da-4688-a38b-8e5a95f42848',
# ...
